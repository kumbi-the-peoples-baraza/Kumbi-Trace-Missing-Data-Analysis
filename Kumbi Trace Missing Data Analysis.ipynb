# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Load the Excel file
file_path = '.ipynb_checkpoints/Anonymous Data.xlsx'
data = pd.read_excel(file_path)

# %%
# Display the first few rows of the dataframe
data.head()
# Out:
#    CASE NUMBER                     NAME MISSING DATE FOUND ALIVE FOUND DEAD  \
# 0            1         JOSEPHINE MLONGO    26/6/2024          NO        YES
# 1            2      JOSEPH MWANGI KAIRU    18/6/2024         YES         NO
# 2            3  RODGERS WANGILA WABOMBA    25/6/2024          NO         NO
# 3            4               NGURE NJAU    25/6/2024          NO        YES
# 4            5           GIBSON KARIUKI    25/6/2024         YES         NO
#
#   Image available  GENDER  AGE  LAST SEEN LOCATION
# 0             YES  FEMALE   26         NAIROBI-CBD
# 1             YES    MALE   28  NAIROBI - KASARANI
# 2             YES    MALE   28       NAIROBI - CBD
# 3             YES    MALE   25       NAIROBI - CBD
# 4             YES    MALE   25      NAIROBI-RONGAI

# %%
#display all the rows of a DataFrame
# Set display options to show all rows
pd.set_option('display.max_rows', None)
# Display the DataFrame
print(data)
# Out:
#     CASE NUMBER                     NAME         MISSING DATE FOUND ALIVE  \
# 0             1         JOSEPHINE MLONGO            26/6/2024          NO
# 1             2      JOSEPH MWANGI KAIRU            18/6/2024         YES
# 2             3  RODGERS WANGILA WABOMBA            25/6/2024          NO
# 3             4               NGURE NJAU            25/6/2024          NO
# 4             5           GIBSON KARIUKI            25/6/2024         YES
# 5             6   EMMANUEL MUKURIA KAMAU            25/6/2024          NO
# 6             7             DIDIER NAMAI            16/7/2024         YES
# 7             8          PIUS COKUMU JNR            16/7/2024         YES
# 8             9     MARVIN MBITHI GADDAH            16/7/2024         YES
# 9            10            LEWIS MWIRIGI            16/7/2024         YES
# 10           11  JOSEPH WAITHAKA OCHIENG            16/7/2024         YES
# 11           12          FREDRICK MBUGUA            16/7/2024         YES
# 12           13              POLO KIMANI            16/7/2024         YES
# 13           14                BOB NJAGI            16/7/2024         YES
# 14           16           WAYNE KING'ARA            19/7/2024         YES
# 15           17              KARL MWANGI            25/7/2024         YES
# 16           18      KELSY ACHIENG OLIRE            24/6/2024         YES
# 17           19                   VIVIAN            14/7/2024          NO
# 18           20         SHELMITH NYAWIRA            17/7/2024         YES
# 19           21        FRANKLINE ONDWARI            17/7/2024          NO
# 20           22       PURITY NJERI GITAU  2024-11-07 00:00:00         YES
# 21           23              IAN NJOROGE            25/6/2024          NO
# 22           24           KAHIU WA NGOMO            23/7/2024         YES
# 23           25            LYDIA KEMUNTO            23/7/2024          NO
# 24           26             SUMEIYA OMAR            23/7/2024         YES
# 25           27           OGUTU BONIFACE            23/7/2024          NO
# 26           28            DERICK KIMANI            23/7/2024         YES
# 27           29              ELVIS LAUDO            23/7/2024         YES
# 28           30                  EPHRAIM  2024-09-07 00:00:00          NO
# 29           31              ANNA MUTHEU            14/7/2024         YES
# 30           32     KIMUTAI RUTO PROPESA            23/7/2024         YES
# 31           33            SOLOMON MAINA            23/7/2024         YES
# 32           34           NELSON OCHIENG            23/7/2024         YES
# 33           35                   GIDEON            22/7/2024         YES
# 34           36         MARTHA KEBIRUNGI            23/7/2024          NO
# 35           37            VICTOR KARASI            23/7/2024         YES
# 36           38              LYDIA OROKO            23/7/2024          NO
# 37           39             JULIUS KAMAU            23/7/2024          NO
# 38           40                  CLINTON            25/6/2024         YES
# 39           41    TERRY FLORENCE NYAOKE            18/7/2024         YES
# 40           42     OWINO EVANCE ONYIEGO            16/7/2024          NO
# 41           43              JOHN MOGOKO            24/7/2024         YES
# 42           44                    KIAMA            23/7/2024         YES
# 43           45           LAWRENCE SYUKI            15/7/2024          NO
# 44           46       ALVIN MAINA MWANGI            23/7/2024          NO
# 45           47          ANITA NDOLOKANI            22/7/2024          NO
# 46           48             CALEB MUNENE            23/7/2024          NO
# 47           49                   GWALLA            23/7/2024          NO
# 48           50              Shad Khalif            25/7/2024          NO
# 49           51           Daniel kabusho            23/7/2024          NO
# 50           52               YAHYA OMAR  2024-03-07 00:00:00          NO
# 51           53           BENJAMIN MUSAU            16/7/2024          NO
# 52           54               SEAN IREGI            14/8/2026          NO
# 53           55      AMOS KIBAKI MUKAMBI            15/5/2029          NO
# 54           56      CHRISTENSEN KIMUTAI            25/7/2024          NO
# 55           57             CHEF ABIGAEL            25/7/2024         YES
# 56           58            KELVIN KATIKU  2024-07-07 00:00:00          NO
# 57           59             KELVIN NGUGI            23/7/2024          NO
# 58           60             DAVIN MURUTU            23/7/2024          NO
# 59           61     DORICUS NEEMA SIMIYU            21/7/2024          NO
# 60           62             MAGRET NABUN            21/7/2024          NO
# 61           63      RYAN BARAKA OCHIENG            22/7/2024         YES
# 62           64           LYDIA ADHIAMBO                  NaN         YES
# 63           65          DICKSON WAMBUGU            22/7/2023          NO
# 64           66   LAWRENCE OGANGO OYWERO           26/11/2023          NO
#
#    FOUND DEAD Image available  GENDER  AGE      LAST SEEN LOCATION
# 0         YES             YES  FEMALE   26             NAIROBI-CBD
# 1          NO             YES    MALE   28      NAIROBI - KASARANI
# 2          NO             YES    MALE   28           NAIROBI - CBD
# 3         YES             YES    MALE   25           NAIROBI - CBD
# 4          NO             YES    MALE   25          NAIROBI-RONGAI
# 5          NO             YES    MALE   25             NAIROBI-CBD
# 6          NO             YES    MALE   24             NAIROBI-CBD
# 7          NO             YES    MALE   26             NAIROBI-CBD
# 8          NO             YES    MALE   25             NAIROBI-CBD
# 9          NO             YES    MALE   25             NAIROBI-CBD
# 10         NO             YES    MALE   17             NAIROBI-CBD
# 11         NO              NO    MALE   25             NAIROBI-CBD
# 12         NO             YES    MALE   26             NAIROBI-CBD
# 13         NO             YES    MALE   30       NAIROBI-KITENGELA
# 14         NO             YES    MALE   27           NAIROBI-NGARA
# 15         NO             YES    MALE   23             NAIROBI-CBD
# 16         NO             YES  FEMALE   25        NAIROBI-KILIMANI
# 17         NO             YES  FEMALE   25       NAIROBI-KITENGELA
# 18         NO             YES  FEMALE   24           NAIROBI-THIKA
# 19        YES             YES    MALE   27  NAIROBI-KIRINYAGA ROAD
# 20         NO             YES  FEMALE   24             NAIROBI-CBD
# 21         NO             YES    MALE   26             NAIROBI-CBD
# 22         NO             YES    MALE   27          NAIROBI-BYPASS
# 23         NO             YES  FEMALE   27                 NYAMIRA
# 24         NO             YES  FEMALE   26                 MOMBASA
# 25         NO             YES    MALE   30                  KISUMU
# 26         NO             YES    MALE   25             NAIROBI-CBD
# 27         NO             YES    MALE   19        NAIROBI-EMBAKASI
# 28         NO             YES    MALE   21             NAIROBI-CBD
# 29         NO             YES  FEMALE   27             NAIROBI-CBD
# 30         NO             YES    MALE   31             NAIROBI-CBD
# 31         NO             YES    MALE   23        NAIROBI-GITHURAI
# 32         NO             YES    MALE   25             NAIROBI-CBD
# 33         NO             YES    MALE   27                 KERICHO
# 34         NO             YES  FEMALE   25             NAIROBI-CBD
# 35         NO             YES    MALE   26             NAIROBI-CBD
# 36         NO             YES  FEMALE   25                 NYAMIRA
# 37         NO             YES    MALE   45             NAIROBI-CBD
# 38         NO             YES    MALE   28             NAIROBI-CBD
# 39         NO             YES  FEMALE   25             NAIROBI-CBD
# 40         NO             YES    MALE   24       NAIROBI-KITENGELA
# 41         NO             YES    MALE   31             NAIROBI-CBD
# 42         NO             YES    MALE   16        NAIROBI-MLOLONGO
# 43         NO             YES    MALE   15          NAIROBI-HURUMA
# 44         NO             YES    MALE   10        NAIROBI-KASARANI
# 45         NO             YES  FEMALE   14         NAIROBI-DANDORA
# 46         NO             YES    MALE   20             NAIROBI-CBD
# 47         NO             YES    MALE   25        NAIROBI-BURUBURU
# 48         NO             YES    MALE   28             NAIROBI-CBD
# 49         NO             YES    MALE   31             NAIROBI-CBD
# 50         NO             YES    MALE   27        NAIROBI-KASARANI
# 51         NO             YES    MALE    7        NAIROBI-EMBAKASI
# 52         NO             YES    MALE   14         NAIROBI-DANDORA
# 53         NO             YES    MALE   14                KAKAMEGA
# 54         NO             YES    MALE    2         NAIROBI-MATHARE
# 55         NO             YES  FEMALE   27                 MOMBASA
# 56         NO             YES    MALE   38             NAIROBI-CBD
# 57        YES             YES    MALE   27        NAIROBI-KASARANI
# 58         NO             YES  FEMALE    7                 BUNGOMA
# 59         NO             YES  FEMALE   10                 BUNGOMA
# 60         NO             YES  FEMALE   16                  NAKURU
# 61         NO             YES    MALE   17                 MOMBASA
# 62         NO             YES  FEMALE   28                 MOMBASA
# 63         NO             YES    MALE   34        NAIROBI-EMBAKASI
# 64         NO             YES    MALE   46                  KISUMU

# %%
#DATA ANALYSIS BASED ON;
#Gender Distribution: Pie chart showing the distribution of missing persons by gender.
#Age Distribution: Histogram showing the distribution of ages of the missing persons.
#Status of Missing Persons: Bar chart showing the number of people found alive, found dead, and still missing.
#Last Seen Location Distribution:Bar chart showing the distribution of the last seen locations of missing persons.
#Missing Dates: Line or bar chart showing the number of people reported missing over time.
#Image Availability: Pie chart showing the percentage of cases with and without images.
#Summary Statistics:
#Gender Distribution:
#Provides a count of each gender.
#Age Distribution:
#Includes count, mean, standard deviation, min, 25%, 50%, 75%, and max.
#Status of Missing Persons:
#Provides a count of each status.
#Image Availability:
#Provides a count of "Yes" and "No".
#Missing Dates:
#Includes count, mean, standard deviation, min, 25%, 50%, 75%, and max for the resampled monthly counts.
#Last Seen Location Distribution:
#Provides a count of each location.

# %%
# Preparing data for visualizations

# %%
# Gender Distribution
gender_distribution = data['GENDER'].value_counts()

# %%
# Age Distribution
age_distribution = data['AGE']

# %%
# Status of Missing Persons
status_distribution = data[['FOUND ALIVE', 'FOUND DEAD']].apply(lambda x: 'Found Alive' if x['FOUND ALIVE'] == 'YES' else ('Found Dead' if x['FOUND DEAD'] == 'YES' else 'Still Missing'), axis=1).value_counts()

# %%
# Last Seen Location Distribution
location_distribution = data['LAST SEEN LOCATION'].value_counts()

# %%
# Image Availability
image_availability = data['Image available'].value_counts()

# %%
# Missing Dates
missing_dates = pd.to_datetime(data['MISSING DATE'], format='%d/%m/%Y').value_counts().sort_index()

# %%
# Plotting each graph separately

# %%
# Gender Distribution
plt.figure(figsize=(8, 6))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.savefig('gender_distribution.svg')
plt.show()

# %%
#Summary Statistics of Gender Distribution
summary_gender = gender_distribution.describe()

# %%
print("Summary Statistics for Gender Distribution:")
print(summary_gender)
# Out:
# Summary Statistics for Gender Distribution:
# count     2.00000
# mean     32.50000
# std      21.92031
# min      17.00000
# 25%      24.75000
# 50%      32.50000
# 75%      40.25000
# max      48.00000
# Name: count, dtype: float64

# %%
 # Age Distribution with a maximum age of 55 years and a scale of 5 years
plt.figure(figsize=(8, 6))
plt.hist(age_distribution, bins=range(0, 56, 5), edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.xticks(range(0, 56, 5))
plt.savefig('age_distribution.svg')
plt.show()

# %%
#Summary statistics of Age Distribution
summary_age = age_distribution.describe()

# %%
print("\nSummary Statistics for Age Distribution:")
print(summary_age)
# Out:
# Summary Statistics for Age Distribution:
# count    65.000000
# mean     24.092308
# std       7.656131
# min       2.000000
# 25%      23.000000
# 50%      25.000000
# 75%      27.000000
# max      46.000000
# Name: AGE, dtype: float64

# %%
# Status of Missing Persons
plt.figure(figsize=(8, 6))
plt.bar(status_distribution.index, status_distribution.values)
plt.title('Status of Missing Persons')
plt.xlabel('Status')
plt.ylabel('Number of People')
plt.savefig('status_of_missing_persons.svg')
plt.show()

# %%
#Summary statistics of Status of Missing Persons
summary_status = status_distribution.describe()

# %%
print("\nSummary Statistics for Status of Missing Persons:")
print(summary_status)
# Out:
# Summary Statistics for Status of Missing Persons:
# count     3.000000
# mean     21.666667
# std      15.502688
# min       4.000000
# 25%      16.000000
# 50%      28.000000
# 75%      30.500000
# max      33.000000
# Name: count, dtype: float64

# %%
plt.figure(figsize=(12, 8))
location_distribution.sort_values().plot(kind='barh')
plt.title('Last Seen Location Distribution')
plt.xlabel('Number of People')
plt.ylabel('Location')
plt.savefig('last_seen_location_distribution.svg')
plt.show()

# %%
#Summary statistics of Last Seen Location Distribution
summary_location = location_distribution.describe()

# %%
print("\nSummary Statistics for Last Seen Location Distribution:")
print(summary_location)
# Out:
# Summary Statistics for Last Seen Location Distribution:
# count    25.000000
# mean      2.600000
# std       5.155903
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      27.000000
# Name: count, dtype: float64

# %%
plt.figure(figsize=(12, 6))
missing_dates.plot(kind='line', marker='o', color='blue')
plt.title('Missing Dates')
plt.xlabel('Date')
plt.ylabel('Number of People')
plt.xticks(rotation=45)
plt.grid(True)
plt.savefig('missing_dates.svg')
plt.show()

# %%
#Summary statistics of Missing Dates
summary_missing_dates = missing_dates.describe()

# %%
print("\nSummary Statistics for Missing Dates:")
print(summary_missing_dates)
# Out:
# Summary Statistics for Missing Dates:
# count    23.000000
# mean      2.782609
# std       4.316528
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      20.000000
# Name: count, dtype: float64

# %%
# Image Availability
plt.figure(figsize=(8, 6))
plt.pie(image_availability, labels=image_availability.index, autopct='%1.1f%%', startangle=140)
plt.title('Image Availability')
plt.savefig('image_availability.svg')
plt.show()

# %%
#Summary Statistics of Image Availability
summary_image_availability = image_availability.describe()

# %%
print("\nSummary Statistics for Image Availability:")
print(summary_image_availability)
# Out:
# Summary Statistics for Image Availability:
# count     2.000000
# mean     32.500000
# std      44.547727
# min       1.000000
# 25%      16.750000
# 50%      32.500000
# 75%      48.250000
# max      64.000000
# Name: count, dtype: float64
